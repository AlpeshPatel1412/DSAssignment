# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# A1: Matplotlib is a 2D, cross-platform, data visualization and graphical plotting library for Python built over NumPy array.
#
# It is used for creating static, animated, and interactive visualizations in Python.

# %% [markdown]
# Below are plots that can be created using Pyplot module:
#
# 1). Line
# 2). Bar
# 3). Histogram
# 4). Box or Whisker plot
# 5). Pie
# 6). Scatter

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot. Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# A2: Scatter plots are used to observe relationship between variables and uses dots to represent the relationship between them. Scatter plots are widely used to represent relation among variables and how change in one affects the other.
#
# If the value along the Y axis seem to increase as X axis increases(or decreases), it could indicate a positive (or negative) linear relationship. Whereas, if the points are randomly distributed with no obvious pattern, it could possibly indicate a lack of dependent relationship.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.xlabel("This is X axis")
plt.ylabel("This is Y axis")
plt.title("My first plot")
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %% [markdown]
# A3: subplot() function is used to added an axes (or subplot) to current figure. It is used to plot two or more graphs in one figure.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2, 2, 1)
plt.plot(x,y,linestyle = 'dashed')
plt.subplot

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2, 2, 2)
plt.plot(x,y,linestyle = 'dotted')

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2, 2, 3)
plt.plot(x,y,linestyle = 'dashdot')

x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2, 2, 4)
plt.plot(x,y,linestyle = 'solid')

plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# A4: A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. The bar plots can be plotted horizontally or vertically.
#
# A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.figure(figsize=(7,4))
plt.bar(company,profit, color = 'orange')

plt.xlabel("IT Companies")
plt.ylabel("Yearly Profit")
plt.title("Financial Result of IT Companies")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [markdown]
# A5: A Box Plot, also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.
#
# Box plots are useful for visualizing the distribution of numerical values in a field. They come in handy for making comparisons across categorical variables and spotting outliers, if any exist in a dataset.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
boxdata = [box1,box2]

# %%
plt.boxplot(boxdata)
plt.show()
